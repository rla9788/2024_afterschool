# %%
import requests

def get_lat_lng(address, api_key):
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params = {
        'address': address,
        'key': api_key
    }
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        if data['status'] == 'OK':
            geometry = data['results'][0]['geometry']['location']
            return geometry['lat'], geometry['lng']
        else:
            raise Exception(f"Geocoding API error: {data['status']}")
    else:
        raise Exception(f"Request error: {response.status_code}")

# Example usage:
api_key = 'AIzaSyCpN60rYlKTr6l_y1IcEhZu2pvyV_oF4dI'
address = '서울특별시 종로구 종로1가'
latitude, longitude = get_lat_lng(address, api_key)
print(f"Latitude: {latitude}, Longitude: {longitude}")


short_code_dic = {
'T1H':('기온','℃'),
'RN1':('1시간 강수량','범주'),
'SKY':('하늘상태','코드값'),
'UUU':('동서바람성분','m/s'),
'VVV':('남북바람성분','m/s'),
'REH':('습도','%'),
'PTY':('강수형태','코드값'),
'LGT':('낙뢰','kA(킬로암페어)'),
'VEC':('풍향','deg'),
'WSD':('풍속','m/s')}
code_dic = {'PTY':('강수형태','코드값'),
'PCP':('1시간 강수량	범주','(1 mm)'),
'REH':('습도','%'),
'SNO':('1시간 신적설	범주','(1 cm)'),
'SKY':('하늘상태','코드값'),
'TMP':('1시간 기온','℃'),
'TMN':('일 최저기온','℃'),
'TMX':('일 최고기온','℃'),
'UUU':('풍속(동서성분)','m/s'),
'VVV':('풍속(남북성분)','m/s'),
'WAV':('파고','M'),
'VEC':('풍향','deg'),
'LGT':('낙뢰','kA(킬로암페어)'),
'WSD':('풍속','m/s')}
import requests
import datetime

def get_weather_forecast(service_key, nx, ny):
    # 현재 날짜와 시간
    base_date = datetime.datetime.now().strftime("%Y%m%d")
    base_time = (datetime.datetime.now() - datetime.timedelta(minutes=30)).strftime("%H%M")  # 30분 전 시간
    if int(base_time) % 100 < 30:
        base_time = (datetime.datetime.now() - datetime.timedelta(minutes=60)).strftime("%H%M")

    url = "http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getUltraSrtFcst"

    #1) [초단기실황조회] 상세기능명세
    #2) [초단기예보조회] 상세기능명세
    #3) [단기예보조회] 상세기능명세
    
    params = {
        "serviceKey": service_key,
        "numOfRows": "60",
        "pageNo": "1",
        "dataType": "JSON",
        "base_date": base_date,
        "base_time": base_time,
        "nx": nx,  # 격자 X 좌표
        "ny": ny   # 격자 Y 좌표
    }

    response = requests.get(url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        if data != None:
            items = data['response']['body']['items']['item']
        
            #print('# 데이터를 출력합니다.')
            #for item in items:
            #    print(f"예보일자: {item['fcstDate']}, 예보시간: {item['fcstTime']}, 예보값: {item['fcstValue']}, 카테고리: {item['category']}")
            return data
        else:
            return print(f"Error: {response.status_code}")
    else:
        print(f"Error: {response.status_code}")
        return None

# 예제 실행
service_key = "UhIXqz3BxyzUBIOobK+yC+lbhlKx4lOWT5glOai8uSuRyW/ea2D6OBF7zp5WnyjTYcXyrzk+PXV2KtNrChOzOQ=="
# Example usage:
api_key = 'AIzaSyCpN60rYlKTr6l_y1IcEhZu2pvyV_oF4dI'
address = '경기도 성남시 분당구 성남대로 601'
latitude, longitude = get_lat_lng(address, api_key)
print(f"Latitude: {latitude}, Longitude: {longitude}")


latitude= float(latitude)
longitude = float(longitude)


nx = int(latitude) #37  # 예시 격자 X 좌표 (서울)
ny = int(latitude) #127 # 예시 격자 Y 좌표 (서울)

weather_data = get_weather_forecast(service_key, nx, ny)

if weather_data != None:
            items = weather_data['response']['body']['items']['item']
        
            print('# 데이터를 출력합니다.')
            for item in items:
                print(f"예보일자: {item['fcstDate']}, 예보시간: {item['fcstTime']}, 예보값: {item['fcstValue']}, 카테고리: {short_code_dic[item['category']]}")
# Out:
# Latitude: 37.5702676, Longitude: 126.9801668
# Latitude: 37.38504940000001, Longitude: 127.1233468
# # 데이터를 출력합니다.
# 예보일자: 20240618, 예보시간: 1800, 예보값: 0, 카테고리: ('낙뢰', 'kA(킬로암페어)')
# 예보일자: 20240618, 예보시간: 1900, 예보값: 0, 카테고리: ('낙뢰', 'kA(킬로암페어)')
# 예보일자: 20240618, 예보시간: 2000, 예보값: 0, 카테고리: ('낙뢰', 'kA(킬로암페어)')
# 예보일자: 20240618, 예보시간: 2100, 예보값: 0, 카테고리: ('낙뢰', 'kA(킬로암페어)')
# 예보일자: 20240618, 예보시간: 2200, 예보값: 0, 카테고리: ('낙뢰', 'kA(킬로암페어)')
# 예보일자: 20240618, 예보시간: 2300, 예보값: 0, 카테고리: ('낙뢰', 'kA(킬로암페어)')
# 예보일자: 20240618, 예보시간: 1800, 예보값: 0, 카테고리: ('강수형태', '코드값')
# 예보일자: 20240618, 예보시간: 1900, 예보값: 0, 카테고리: ('강수형태', '코드값')
# 예보일자: 20240618, 예보시간: 2000, 예보값: 0, 카테고리: ('강수형태', '코드값')
# 예보일자: 20240618, 예보시간: 2100, 예보값: 0, 카테고리: ('강수형태', '코드값')
# 예보일자: 20240618, 예보시간: 2200, 예보값: 0, 카테고리: ('강수형태', '코드값')
# 예보일자: 20240618, 예보시간: 2300, 예보값: 0, 카테고리: ('강수형태', '코드값')
# 예보일자: 20240618, 예보시간: 1800, 예보값: 강수없음, 카테고리: ('1시간 강수량', '범주')
# 예보일자: 20240618, 예보시간: 1900, 예보값: 강수없음, 카테고리: ('1시간 강수량', '범주')
# ...
